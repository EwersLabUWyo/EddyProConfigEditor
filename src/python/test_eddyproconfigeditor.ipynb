# %%
from copy import copy
from collections.abc import Sequence
import datetime

from pandas import DataFrame

from eddyproconfigeditor import EddyproConfigEditor
from util import compare_configs

# %%
base = EddyproConfigEditor('/Users/alex/Documents/Work/UWyo/Research/Flux Pipeline Project/Eddypro-ec-testing/investigate_eddypro/ini/base.eddypro')

# %% [markdown]
# # Primary Utilities

# %%
compare_configs(base.to_pandas(), base.copy().to_pandas())
# Out:
# Empty DataFrame
# Columns: [Value_base, Section, Option, Value_base]
# Index: []

# %% [markdown]
# # Basic
# * out path
# * project start date
# * project end date
# * project date range
# * missing samples allowance
# * flux averaging interval
# * north reference
# * project id

# %%
ref = base.copy()

ref.Basic.set_out_path(d='test')

compare_configs(base.to_pandas(), ref.to_pandas())
# Out:
#    Section    Option                                         Value_base  \
# 0  Project  out_path  /Users/alex/Documents/Work/UWyo/Research/Flux ...
#
#   Value_base
# 0       test

# %%
ref = base.copy()

ref.Basic.set_project_start_date('2019-01-01 12:12')

compare_configs(base.to_pandas(), ref.to_pandas())
# Out:
#    Section         Option  Value_base  Value_base
# 0  Project  pr_start_date  2020-06-21  2019-01-01
# 1  Project  pr_start_time       00:00       12:12

# %%
ref = base.copy()

ref.Basic.set_project_end_date('2019-01-01 12:12')

compare_configs(base.to_pandas(), ref.to_pandas())
# Out:
#    Section       Option  Value_base  Value_base
# 0  Project  pr_end_date  2020-07-22  2019-01-01
# 1  Project  pr_end_time       00:00       12:12

# %%
ref = base.copy()

ref.Basic.set_project_date_range('2019-01-01 12:12', '2023-03-03 13:13')

compare_configs(base.to_pandas(), ref.to_pandas())
# Out:
#    Section         Option  Value_base  Value_base
# 0  Project    pr_end_date  2020-07-22  2023-03-03
# 1  Project    pr_end_time       00:00       13:13
# 2  Project  pr_start_date  2020-06-21  2019-01-01
# 3  Project  pr_start_time       00:00       12:12

# %%
ref = base.copy()
ref.Basic.set_missing_samples_allowance(pct=39)
compare_configs(base.to_pandas(), ref.to_pandas())
# Out:
#                Section    Option Value_base Value_base
# 0  RawProcess_Settings  max_lack         10         39

# %%
ref = base.copy()
ref.Basic.set_north_reference('mag')
compare_configs(base.to_pandas(), ref.to_pandas())

ref = base.copy()
ref.Basic.set_north_reference('geo', 80, '2012-01-01 00:00')
display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
#               Section         Option  Value_base  Value_base
# 0  RawProcess_General       dec_date  2023-12-31  2012-01-01
# 1  RawProcess_General        mag_dec           0          80
# 2  RawProcess_General  use_geo_north           0           1

# %%
ref = base.copy()
ref.Basic.set_project_id('test')
display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
#    Section      Option Value_base Value_base
# 0  Project  project_id       base       test

# %% [markdown]
# # Advanced
# * Processing options
# * Statistical analysis
# * Spectral analysis
# * Output options

# %% [markdown]
# ## Processing options
# * wind speed offsets
# * axis rotations for tilt correction
# * computation of turbulent fluctuations
# * timelag compensation
# * compensation for density fluctuations

# %%
ref = base.copy()

ref.Adv.Proc.set_wind_speed_measurement_offsets(10, 10, 10)
display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
#                Section    Option Value_base Value_base
# 0  RawProcess_Settings  u_offset          0         10
# 1  RawProcess_Settings  v_offset          0         10
# 2  RawProcess_Settings  w_offset          0         10

# %%
ref = base.copy()
ref.Adv.Proc.set_axis_rotations_for_tilt_correction(
    method='none')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_axis_rotations_for_tilt_correction(
    method='triple_rotations')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_axis_rotations_for_tilt_correction(
    method='planar_fit',
    pf_file='test')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_axis_rotations_for_tilt_correction(
    method='planar_fit_nvb',
    pf_file='test')
display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
#                Section    Option Value_base Value_base
# 0  RawProcess_Settings  rot_meth          1          0
#                Section    Option Value_base Value_base
# 0  RawProcess_Settings  rot_meth          1          2
#                               Section    Option Value_base Value_base
# 0                 RawProcess_Settings  rot_meth          1          3
# 1  RawProcess_TiltCorrection_Settings   pf_file                  test
# 2  RawProcess_TiltCorrection_Settings   pf_mode          1          0
#                               Section    Option Value_base Value_base
# 0                 RawProcess_Settings  rot_meth          1          4
# 1  RawProcess_TiltCorrection_Settings   pf_file                  test
# 2  RawProcess_TiltCorrection_Settings   pf_mode          1          0

# %% [markdown]
# slight format change: compare base to reference when using manual planar fit

# %%
ref = base.copy()
kwargs = dict(
    w_max=0.9,
    u_min=0.05,
    num_per_sector_min=420,
    north_offset=42,
    sectors=[(1, 30), (0, 30), (0, 300)],
    start='project',
    end='project',
    fix_method='CCW')
ref.Adv.Proc.set_axis_rotations_for_tilt_correction(
    method='planar_fit',
    configure_planar_fit_settings_kwargs=kwargs)
display(base.to_pandas().query('Section == "RawProcess_TiltCorrection_Settings"'))
display(ref.to_pandas().query('Section == "RawProcess_TiltCorrection_Settings"'))
# Out:
#                                 Section              Option       Value  Name
# 338  RawProcess_TiltCorrection_Settings         pf_end_date  2020-07-22  base
# 339  RawProcess_TiltCorrection_Settings         pf_end_time       00:00  base
# 340  RawProcess_TiltCorrection_Settings             pf_file              base
# 341  RawProcess_TiltCorrection_Settings              pf_fix           0  base
# 342  RawProcess_TiltCorrection_Settings  pf_min_num_per_sec           0  base
# 343  RawProcess_TiltCorrection_Settings             pf_mode           1  base
# 344  RawProcess_TiltCorrection_Settings     pf_north_offset           0  base
# 345  RawProcess_TiltCorrection_Settings       pf_start_date  2020-06-21  base
# 346  RawProcess_TiltCorrection_Settings       pf_start_time              base
# 347  RawProcess_TiltCorrection_Settings           pf_subset           0  base
# 348  RawProcess_TiltCorrection_Settings            pf_u_min      -0.001  base
# 349  RawProcess_TiltCorrection_Settings            pf_w_max       0.099  base
#                                 Section               Option       Value  Name
# 338  RawProcess_TiltCorrection_Settings          pf_end_date  2020-07-22  base
# 339  RawProcess_TiltCorrection_Settings          pf_end_time       00:00  base
# 340  RawProcess_TiltCorrection_Settings              pf_file              base
# 341  RawProcess_TiltCorrection_Settings               pf_fix           1  base
# 342  RawProcess_TiltCorrection_Settings   pf_min_num_per_sec         420  base
# 343  RawProcess_TiltCorrection_Settings              pf_mode           1  base
# 344  RawProcess_TiltCorrection_Settings      pf_north_offset          42  base
# 350  RawProcess_TiltCorrection_Settings  pf_sector_1_exclude           1  base
# 351  RawProcess_TiltCorrection_Settings    pf_sector_1_width          30  base
# 352  RawProcess_TiltCorrection_Settings  pf_sector_2_exclude           0  base
# 353  RawProcess_TiltCorrection_Settings    pf_sector_2_width          30  base
# 354  RawProcess_TiltCorrection_Settings  pf_sector_3_exclude           0  base
# 355  RawProcess_TiltCorrection_Settings    pf_sector_3_width         300  base
# 345  RawProcess_TiltCorrection_Settings        pf_start_date  2020-06-21  base
# 346  RawProcess_TiltCorrection_Settings        pf_start_time              base
# 347  RawProcess_TiltCorrection_Settings            pf_subset           0  base
# 348  RawProcess_TiltCorrection_Settings             pf_u_min        0.05  base
# 349  RawProcess_TiltCorrection_Settings             pf_w_max         0.9  base

# %% [markdown]
# slight format change: compare base to reference when using manual planar fit nvb

# %%
ref = base.copy()
kwargs = dict(
    w_max=0.9,
    u_min=0.05,
    num_per_sector_min=420,
    north_offset=42,
    sectors=[(1, 30), (0, 30), (0, 300)],
    start='project',
    end='project',
    fix_method='CCW')
ref.Adv.Proc.set_axis_rotations_for_tilt_correction(
    method='planar_fit_nvb',
    configure_planar_fit_settings_kwargs=kwargs)
display(base.to_pandas().query('Section == "RawProcess_TiltCorrection_Settings"'))
display(ref.to_pandas().query('Section == "RawProcess_TiltCorrection_Settings"'))
# display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
#                                 Section              Option       Value  Name
# 338  RawProcess_TiltCorrection_Settings         pf_end_date  2020-07-22  base
# 339  RawProcess_TiltCorrection_Settings         pf_end_time       00:00  base
# 340  RawProcess_TiltCorrection_Settings             pf_file              base
# 341  RawProcess_TiltCorrection_Settings              pf_fix           0  base
# 342  RawProcess_TiltCorrection_Settings  pf_min_num_per_sec           0  base
# 343  RawProcess_TiltCorrection_Settings             pf_mode           1  base
# 344  RawProcess_TiltCorrection_Settings     pf_north_offset           0  base
# 345  RawProcess_TiltCorrection_Settings       pf_start_date  2020-06-21  base
# 346  RawProcess_TiltCorrection_Settings       pf_start_time              base
# 347  RawProcess_TiltCorrection_Settings           pf_subset           0  base
# 348  RawProcess_TiltCorrection_Settings            pf_u_min      -0.001  base
# 349  RawProcess_TiltCorrection_Settings            pf_w_max       0.099  base
#                                 Section               Option       Value  Name
# 338  RawProcess_TiltCorrection_Settings          pf_end_date  2020-07-22  base
# 339  RawProcess_TiltCorrection_Settings          pf_end_time       00:00  base
# 340  RawProcess_TiltCorrection_Settings              pf_file              base
# 341  RawProcess_TiltCorrection_Settings               pf_fix           1  base
# 342  RawProcess_TiltCorrection_Settings   pf_min_num_per_sec         420  base
# 343  RawProcess_TiltCorrection_Settings              pf_mode           1  base
# 344  RawProcess_TiltCorrection_Settings      pf_north_offset          42  base
# 350  RawProcess_TiltCorrection_Settings  pf_sector_1_exclude           1  base
# 351  RawProcess_TiltCorrection_Settings    pf_sector_1_width          30  base
# 352  RawProcess_TiltCorrection_Settings  pf_sector_2_exclude           0  base
# 353  RawProcess_TiltCorrection_Settings    pf_sector_2_width          30  base
# 354  RawProcess_TiltCorrection_Settings  pf_sector_3_exclude           0  base
# 355  RawProcess_TiltCorrection_Settings    pf_sector_3_width         300  base
# 345  RawProcess_TiltCorrection_Settings        pf_start_date  2020-06-21  base
# 346  RawProcess_TiltCorrection_Settings        pf_start_time              base
# 347  RawProcess_TiltCorrection_Settings            pf_subset           0  base
# 348  RawProcess_TiltCorrection_Settings             pf_u_min        0.05  base
# 349  RawProcess_TiltCorrection_Settings             pf_w_max         0.9  base

# %%
ref = base.copy()
ref.Adv.Proc.set_turbulent_fluctuations(detrend_method='block')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_turbulent_fluctuations(detrend_method='linear')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_turbulent_fluctuations(detrend_method='running_mean')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_turbulent_fluctuations(detrend_method='exponential_running_mean')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_turbulent_fluctuations(detrend_method='exponential_running_mean', time_constant=7)
display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
# Empty DataFrame
# Columns: [Value_base, Section, Option, Value_base]
# Index: []
#                Section        Option Value_base Value_base
# 0  RawProcess_Settings  detrend_meth          0          1
# 1  RawProcess_Settings     timeconst      250.0          0
#                Section        Option Value_base          Value_base
# 0  RawProcess_Settings  detrend_meth          0                   2
# 1  RawProcess_Settings     timeconst      250.0  250.00000000000003
#                Section        Option Value_base          Value_base
# 0  RawProcess_Settings  detrend_meth          0                   3
# 1  RawProcess_Settings     timeconst      250.0  250.00000000000003
#                Section        Option Value_base Value_base
# 0  RawProcess_Settings  detrend_meth          0          3
# 1  RawProcess_Settings     timeconst      250.0        420

# %%
ref = base.copy()
ref.Adv.Proc.set_timelag_compensations(method='none')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_timelag_compensations(method='constant')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_timelag_compensations(method='covariance_maximization_with_default')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_timelag_compensations(method='covariance_maximization')
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
kwargs=dict(
    start='2021-01-01 10:10',
    end='2021-01-01 10:11',
    pg_range=1.4,
    n_rh_classes=9,
    le_min_flux=19,
    co2_min_flux=10,
    ch4_min_flux=0.1,
    gas4_min_flux=0.01,
    co2_lags=(-10, -9),
    ch4_lags=(-11, 9),
    h2o_lags=(12, 13),
    gas4_lags=(9, 10))
ref.Adv.Proc.set_timelag_compensations(method='automatic_optimization', configure_TimelagAutoOpt_kwargs=kwargs)
display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
#                Section     Option Value_base Value_base
# 0  RawProcess_Settings  tlag_meth          4          0
#                Section     Option Value_base Value_base
# 0  RawProcess_Settings  tlag_meth          4          1
#                Section     Option Value_base Value_base
# 0  RawProcess_Settings  tlag_meth          4          2
#                Section     Option Value_base Value_base
# 0  RawProcess_Settings  tlag_meth          4          3
# /Users/alex/Documents/Work/UWyo/Research/Flux Pipeline Project/Eddypro-ec-testing/src/python/eddyproconfigeditor.py:1254: UserWarning: insufficient overlap (False days) between time lag optimization time window (2021-01-01 10:10 -> 2021-01-01 10:11) and project time window ({'start': datetime.datetime(2020, 6, 21, 0, 0)} -> {'end': datetime.datetime(2020, 7, 22, 0, 0)}). At least 30 days are required
#   warnings.warn(f'insufficient overlap ({overlap} days) between time lag optimization time window ({to_start} -> {to_end}) and project time window ({self.root.Basic.get_project_start_date()} -> {self.root.Basic.get_project_end_date()}). At least 30 days are required')
#                                     Section            Option  Value_base  \
# 0   RawProcess_TimelagOptimization_Settings    to_ch4_max_lag     -1000.1
# 1   RawProcess_TimelagOptimization_Settings   to_ch4_min_flux       0.200
# 2   RawProcess_TimelagOptimization_Settings    to_ch4_min_lag     -1000.1
# 3   RawProcess_TimelagOptimization_Settings    to_co2_max_lag     -1000.1
# 4   RawProcess_TimelagOptimization_Settings   to_co2_min_flux       2.000
# 5   RawProcess_TimelagOptimization_Settings    to_co2_min_lag     -1000.1
# 6   RawProcess_TimelagOptimization_Settings       to_end_date  2020-06-22
# 7   RawProcess_TimelagOptimization_Settings       to_end_time       00:00
# 8   RawProcess_TimelagOptimization_Settings   to_gas4_max_lag     -1000.1
# 9   RawProcess_TimelagOptimization_Settings  to_gas4_min_flux       0.020
# 10  RawProcess_TimelagOptimization_Settings   to_gas4_min_lag     -1000.1
# 11  RawProcess_TimelagOptimization_Settings    to_h2o_max_lag     -1000.1
# 12  RawProcess_TimelagOptimization_Settings    to_h2o_min_lag     -1000.1
# 13  RawProcess_TimelagOptimization_Settings     to_h2o_nclass          10
# 14  RawProcess_TimelagOptimization_Settings    to_le_min_flux        20.0
# 15  RawProcess_TimelagOptimization_Settings       to_pg_range         1.5
# 16  RawProcess_TimelagOptimization_Settings     to_start_date  2020-06-21
# 17  RawProcess_TimelagOptimization_Settings     to_start_time       00:00
#
#     Value_base
# 0           -9
# 1          0.1
# 2          -10
# 3            9
# 4           10
# 5          -11
# 6   2021-01-01
# 7        10:11
# 8           10
# 9         0.01
# 10           9
# 11          13
# 12          12
# 13           9
# 14          19
# 15         1.4
# 16  2021-01-01
# 17       10:10

# %%
ref = base.copy()
ref.Adv.Proc.set_compensation_of_density_fluctuations(
    enable=True,
    burba_method='multiple',
    day_bot=(1, 2, 3, 4),
    day_spar=(10, 20, 30, 40),
    day_top=(100, 200, 300, 400),
    night_bot=(1000, 2000, 3000, 4000),
    night_spar=(.1, .2, .3, .4),
    night_top=(.01, .02, .03, .04),
)
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Proc.set_compensation_of_density_fluctuations(
    enable=True,
    burba_method='simple',
    day_bot=(1, 2,),
    day_spar=(10, 20),
    day_top=(100, 200),
    night_bot=(1000, 2000),
    night_spar=(.1, .2),
    night_top=(.01, .02),
)
display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
#                 Section         Option   Value_base Value_base
# 0   RawProcess_Settings        bu_corr            0          1
# 1   RawProcess_Settings       bu_multi            0          1
# 2   RawProcess_Settings     m_day_bot1   2.80000000          1
# 3   RawProcess_Settings     m_day_bot2  -0.06810000          2
# 4   RawProcess_Settings     m_day_bot3   0.00210000          3
# 5   RawProcess_Settings     m_day_bot4  -0.33400000          4
# 6   RawProcess_Settings    m_day_spar1   0.30000000         10
# 7   RawProcess_Settings    m_day_spar2  -0.00070000         20
# 8   RawProcess_Settings    m_day_spar3   0.00060000         30
# 9   RawProcess_Settings    m_day_spar4  -0.04400000         40
# 10  RawProcess_Settings     m_day_top1  -0.10000000        100
# 11  RawProcess_Settings     m_day_top2  -0.00440000        200
# 12  RawProcess_Settings     m_day_top3   0.00110000        300
# 13  RawProcess_Settings     m_day_top4  -0.02200000        400
# 14  RawProcess_Settings   m_night_bot1   0.50000000       1000
# 15  RawProcess_Settings   m_night_bot2  -0.11600000       2000
# 16  RawProcess_Settings   m_night_bot3   0.00870000       3000
# 17  RawProcess_Settings   m_night_bot4  -0.20600000       4000
# 18  RawProcess_Settings  m_night_spar1  -2.10000000        0.1
# 19  RawProcess_Settings  m_night_spar2  -0.02000000        0.2
# 20  RawProcess_Settings  m_night_spar3   0.00700000        0.3
# 21  RawProcess_Settings  m_night_spar4   0.02600000        0.4
# 22  RawProcess_Settings   m_night_top1  -1.70000000       0.01
# 23  RawProcess_Settings   m_night_top2  -0.01600000       0.02
# 24  RawProcess_Settings   m_night_top3   0.00510000       0.03
# 25  RawProcess_Settings   m_night_top4  -0.02900000       0.04
#                 Section               Option   Value_base Value_base
# 0   RawProcess_Settings              bu_corr            0          1
# 1   RawProcess_Settings       l_day_bot_gain   0.94400000          1
# 2   RawProcess_Settings     l_day_bot_offset   2.57000000          2
# 3   RawProcess_Settings      l_day_spar_gain   1.01000000         10
# 4   RawProcess_Settings    l_day_spar_offset   0.36000000         20
# 5   RawProcess_Settings       l_day_top_gain   1.00500000        100
# 6   RawProcess_Settings     l_day_top_offset   0.24000000        200
# 7   RawProcess_Settings     l_night_bot_gain   0.88300000       1000
# 8   RawProcess_Settings   l_night_bot_offset   2.17000000       2000
# 9   RawProcess_Settings    l_night_spar_gain   1.01000000        0.1
# 10  RawProcess_Settings  l_night_spar_offset  -0.17000000        0.2
# 11  RawProcess_Settings     l_night_top_gain   1.00800000       0.01
# 12  RawProcess_Settings   l_night_top_offset  -0.41000000       0.02

# %% [markdown]
# ## Statistical analysis
# * despike

# %%
ref = base.copy()
ref.Adv.Stat.set_spike_count_removal(
    enable=True,
    method='M13',
    accepted=0.9,
    linterp=False,
    max_consec_outliers=4
)
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Stat.set_spike_count_removal(
    enable=False,
    method='M13',
    accepted=0.9,
    linterp=False,
    max_consec_outliers=4
)
display(compare_configs(base.to_pandas(), ref.to_pandas()))

ref = base.copy()
ref.Adv.Stat.set_spike_count_removal(
    enable=False,
    method='VM97',
    accepted=0.9,
    linterp=False,
    max_consec_outliers=4,
    w=3,
    co2=3.4,
    h2o=3.6,
    ch4=7.9,
    gas4=8.1,
    others=3.55
)
display(compare_configs(base.to_pandas(), ref.to_pandas()))
# Out:
#                         Section      Option Value_base Value_base
# 0  RawProcess_ParameterSettings  despike_vm          0          1
# 1  RawProcess_ParameterSettings   sr_lim_hf        1.0        0.9
# 2           RawProcess_Settings   filter_sr          1          0
#             Section   Option Value_base Value_base
# 0  RawProcess_Tests  test_sr          1          0
#             Section   Option Value_base Value_base
# 0  RawProcess_Tests  test_sr          1          0

# %%
ref.to_eddypro(ini_file='/Users/alex/Documents/Work/UWyo/Research/Flux Pipeline Project/Eddypro-ec-testing/investigate_eddypro/ini/test.eddypro', out_path='keep')
# Out:
# /Users/alex/Documents/Work/UWyo/Research/Flux Pipeline Project/Eddypro-ec-testing/src/python/eddyproconfigeditor.py:298: UserWarning: timelag auto opt window (2020-06-21 00:00 -> 2020-06-22 00:00) does not sufficiently overlap with project date range (2020-06-21 00:00 -> 2020-07-22 00:00). There must be at least 30 days of overlap.
#   warnings.warn(f'timelag auto opt window ({to_start.strftime(r"%Y-%m-%d %H:%M")} -> {to_end.strftime(r"%Y-%m-%d %H:%M")}) does not sufficiently overlap with project date range ({start.strftime(r"%Y-%m-%d %H:%M")} -> {end.strftime(r"%Y-%m-%d %H:%M")}). There must be at least 30 days of overlap.')
